# %% [markdown]
# ## Initial Setup

# %%
import nltk
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('PreprocessedDataset.csv')
df
# Out:
#       Unnamed: 0               University Abbreviation  \
# 0              0  University of Newcastle           NU
# 1              1  University of Newcastle           NU
# 2              2  University of Newcastle           NU
# 3              3  University of Newcastle           NU
# 4              4  University of Newcastle           NU
# ...          ...                      ...          ...
# 1318        1318  University of Newcastle           NU
# 1319        1319  University of Newcastle           NU
# 1320        1320  University of Newcastle           NU
# 1321        1321  University of Newcastle           NU
# 1322        1322  University of Newcastle           NU
#
#                                 Department  \
# 0     Architecture, Planning and Landscape
# 1     Architecture, Planning and Landscape
# 2     Architecture, Planning and Landscape
# 3     Architecture, Planning and Landscape
# 4     Architecture, Planning and Landscape
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Courses per department analysis

# %%
groupbydf = df.groupby(['Department']).count()
lessons_per_dep_df = groupbydf.loc[:,'Unit']
lessons_per_dep_df
# Out:
# Department
# Architecture, Planning and Landscape               26
# Arts and Cultures                                  80
# Biomedical Sciences                                87
# Computing Science                                  24
# Education, Communication and Language Sciences     10
# Engineering                                        99
# English Literature, Language and Linguistics       74
# Geography, Politics and Sociology                 124
# History, Classics and Archaeology                 150
# Law                                                 9
# Mathematics and Statistics                         72
# Modern Languages                                  177
# NUBS Postgraduate                                  26
# Natural and Environmental Sciences                138
# Newcastle University Business School              156
# Philosophical Studies                              35
# Psychology                                         36
# Name: Unit, dtype: int64

# %%
lessons_per_dep_df.plot(kind='line', figsize=(49,5))
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
lessons_per_dep_df.describe()
# Out:
# count     17.000000
# mean      77.823529
# std       55.161394
# min        9.000000
# 25%       26.000000
# 50%       74.000000
# 75%      124.000000
# max      177.000000
# Name: Unit, dtype: float64

# %%
groupbydf.rename(inplace=True,columns={'University':'Courses'})
groupbydf.boxplot(column=['Courses'],figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Courses' Units Analysis

# %%
df['Unit'].describe()
# Out:
# count    1323.000000
# mean       17.698413
# std         9.460351
# min         0.000000
# 25%        10.000000
# 50%        20.000000
# 75%        20.000000
# max       120.000000
# Name: Unit, dtype: float64

# %%
df.boxplot(column=['Unit'],figsize=(10,5))
# Out:
# <AxesSubplot:>
